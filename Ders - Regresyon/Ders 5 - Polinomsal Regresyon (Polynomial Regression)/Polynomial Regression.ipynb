# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd '/content/drive/MyDrive/Python ile Makine Öğrenmesi/Ders 5 - Polinomsal Regresyon (Polynomial Regression)'
# !ls()
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Python ile Makine Öğrenmesi/Ders 5 - Polinomsal Regresyon (Polynomial Regression)
#  maaslar.csv  'Polynomial Regression.ipynb'

# %%
import numpy as np
import pandas as pd

# %%
veriler = pd.read_csv("maaslar.csv")
veriler
# Out:
#               unvan  Egitim Seviyesi   maas
# 0             Cayci                1   2250
# 1          Sekreter                2   2500
# 2  Uzman Yardimcisi                3   3000
# 3             Uzman                4   4000
# 4  Proje Yoneticisi                5   5500
# 5               Sef                6   7500
# 6             Mudur                7  10000
# 7          Direktor                8  15000
# 8           C-level                9  25000
# 9               CEO               10  50000

# %%
x = veriler.iloc[:,1:2]
y = veriler.iloc[:,2:]

X = x.values
Y = y.values

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X,Y)
# Out:
# LinearRegression()

# %%
import matplotlib.pyplot as plt

plt.scatter(x,y, color="red")
plt.plot(x,lr.predict(X), color="blue")
plt.show()

# %%
from sklearn.preprocessing import PolynomialFeatures

pf = PolynomialFeatures(degree = 3)

#verileri polinomal hale çeviriyoruz
x_poly = pf.fit_transform(X)
x_poly
#x^0, x^1,x^2
#X değeri 1-10 arası olsuğu için karesi de 1-100 arası
# Out:
# array([[   1.,    1.,    1.,    1.],
#        [   1.,    2.,    4.,    8.],
#        [   1.,    3.,    9.,   27.],
#        [   1.,    4.,   16.,   64.],
#        [   1.,    5.,   25.,  125.],
#        [   1.,    6.,   36.,  216.],
#        [   1.,    7.,   49.,  343.],
#        [   1.,    8.,   64.,  512.],
#        [   1.,    9.,   81.,  729.],
#        [   1.,   10.,  100., 1000.]])

# %%
lr2 = LinearRegression()
lr2.fit(x_poly, y)

plt.scatter(X,Y)
plt.plot(X,lr2.predict(pf.fit_transform(X)), color="blue")
plt.show()

# %%
print(lr.predict([[11]]))
print(lr2.predict(pf.fit_transform([[11]])))
# Out:
# [[34716.66666667]]
# [[73766.66666666]]
