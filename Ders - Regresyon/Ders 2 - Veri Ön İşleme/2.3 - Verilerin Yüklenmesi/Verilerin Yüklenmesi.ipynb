# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd '/content/drive/MyDrive/Python ile Makine Öğrenmesi/2.3 - Verilerin Yüklenmesi'
# !ls
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Python ile Makine Öğrenmesi/2.3 - Verilerin Yüklenmesi
#  veriler.csv  'Verilerin Yüklenmesi.ipynb'

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#veri yükleme
veriler = pd.read_csv('veriler.csv')

# %%
#veri önişleme
veriler[['boy']]
veriler[['boy', 'kilo']]
# Out:
#     boy  kilo
# 0   130    30
# 1   125    36
# 2   135    34
# 3   133    30
# 4   129    38
# 5   180    90
# 6   190    80
# 7   175    90
# 8   177    60
# 9   185   105
# 10  165    55
# 11  155    50
# 12  160    58
# 13  162    59
# 14  167    62
# 15  174    70
# 16  193    90
# 17  187    80
# 18  183    88
# 19  159    40
# 20  164    66
# 21  166    56
