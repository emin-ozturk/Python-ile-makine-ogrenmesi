# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd '/content/drive/MyDrive/Python ile Makine Öğrenmesi/Modelin Kaydedilmesi'
# !ls
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Python ile Makine Öğrenmesi/Modelin Kaydedilmesi
# 'Modelin Kaydedilmesi.ipynb'

# %%
import pandas as pd
url = 'https://bilkav.com/satislar.csv'
veriler = pd.read_csv(url)
veriler = veriler.values
X = veriler[:,0:1]
Y = veriler[:,1]
bolme = 0.33

from sklearn import model_selection
X_train, X_test, Y_train, Y_test = model_selection.train_test_split(X, Y, test_size = bolme)

from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train, Y_train)
print(lr.predict(X_test))

import pickle

# model kaydetme
dosya = 'model.kayıt'
pickle.dump(lr, open(dosya, 'wb'))

# model okuma
yuklenen = pickle.load(open(dosya, 'rb'))
print(yuklenen.predict(X_test))
# Out:
# [19659.05722566 17274.34901059 36352.01473116 29197.89008595
#  48275.55580652 29197.89008595 29992.79282431 28402.98734759
#  25223.37639416 24428.47365581]
# [19659.05722566 17274.34901059 36352.01473116 29197.89008595
#  48275.55580652 29197.89008595 29992.79282431 28402.98734759
#  25223.37639416 24428.47365581]
