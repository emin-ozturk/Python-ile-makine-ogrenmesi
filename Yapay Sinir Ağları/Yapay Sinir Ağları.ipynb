# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd '/content/drive/MyDrive/Python ile Makine Öğrenmesi/Yapay Sinir Ağları'
# !ls
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Python ile Makine Öğrenmesi/Yapay Sinir Ağları
# 'Yapay Sinir Ağları.ipynb'

# %% [markdown]
# # **Kütüphane Yüklenmesi**

# %%
# !pip install --no-deps git+git://github.com/Theano/Theano.git

# %%
# !pip install --upgrade tensorflow

# %%
# !pip install keras

# %%
# !pip install https://storage.googleapis.com/tensorflow/mac/cpu/tensorflow-1.8.0-py3-none-any.whl

# %% [markdown]
# Tensorflow

# %%
# !pip install --upgrade tensorflow

# %%
import tensorflow as tf

hello = tf.constant('sd')
print(hello.numpy().decode())
# Out:
# sd

# %%
#1.kutuphaneler
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

#2.veri onisleme
#2.1.veri yukleme
veriler = pd.read_csv('Churn_Modelling.csv')
#pd.read_csv("veriler.csv")
#test
print(veriler)

#veri on isleme

X= veriler.iloc[:,3:13].values
Y = veriler.iloc[:,13].values


#encoder: Kategorik -> Numeric
from sklearn import preprocessing

le = preprocessing.LabelEncoder()
X[:,1] = le.fit_transform(X[:,1])

le2 = preprocessing.LabelEncoder()
X[:,2] = le2.fit_transform(X[:,2])

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

ohe = ColumnTransformer([("ohe", OneHotEncoder(dtype=float),[1])],
                        remainder="passthrough"
                        )
X = ohe.fit_transform(X)
X = X[:,1:]




#verilerin egitim ve test icin bolunmesi
from sklearn.model_selection import train_test_split
x_train, x_test,y_train,y_test = train_test_split(X,Y,test_size=0.33, random_state=0)


#verilerin olceklenmesi
from sklearn.preprocessing import StandardScaler

sc=StandardScaler()

X_train = sc.fit_transform(x_train)
X_test = sc.fit_transform(x_test)


#3 Yapay Sinir ağı
import keras
from keras.models import Sequential
from keras.layers import Dense

classifier = Sequential()

classifier.add(Dense(6, kernel_initializer = 'uniform', activation = 'relu' , input_dim = 11))

classifier.add(Dense(6, kernel_initializer = 'uniform', activation = 'relu'))

classifier.add(Dense(1, kernel_initializer = 'uniform', activation = 'sigmoid'))

classifier.compile(optimizer = 'adam', loss =  'binary_crossentropy' , metrics = ['accuracy'] )

classifier.fit(X_train, y_train, epochs=50)

y_pred = classifier.predict(X_test)

y_pred = (y_pred > 0.5)

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,y_pred)

print(cm)
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]
# Epoch 1/50
# 210/210 [==============================] - 5s 3ms/step - loss: 0.5949 - accuracy: 0.7975
# Epoch 2/50
# 210/210 [==============================] - 0s 2ms/step - loss: 0.4389 - accuracy: 0.7979
# Epoch 3/50
# 210/210 [==============================] - 0s 2ms/step - loss: 0.4305 - accuracy: 0.7979
# Epoch 4/50
# 210/210 [==============================] - 0s 2ms/step - loss: 0.4276 - accuracy: 0.7979
# Epoch 5/50
# 210/210 [==============================] - 0s 2ms/step - loss: 0.4260 - accuracy: 0.7979
# Epoch 6/50
# 210/210 [==============================] - 0s 2ms/step - loss: 0.4245 - accuracy: 0.7979
# Epoch 7/50
# 210/210 [==============================] - 0s 2ms/step - loss: 0.4224 - accuracy: 0.8045
# Epoch 8/50
# 210/210 [==============================] - 0s 2ms/step - loss: 0.4198 - accuracy: 0.8172
# Epoch 9/50
# 210/210 [==============================] - 0s 2ms/step - loss: 0.4175 - accuracy: 0.8206
# Epoch 10/50
# 210/210 [==============================] - 0s 2ms/step - loss: 0.4155 - accuracy: 0.8236
# Epoch 11/50
# 210/210 [==============================] - 0s 2ms/step - loss: 0.4132 - accuracy: 0.8264
# Epoch 12/50
# 210/210 [==============================] - 0s 2ms/step - loss: 0.4111 - accuracy: 0.8281
# Epoch 13/50
# 210/210 [==============================] - 0s 2ms/step - loss: 0.4092 - accuracy: 0.8304
# Epoch 14/50
# 210/210 [==============================] - 0s 2ms/step - loss: 0.4073 - accuracy: 0.8310
# Epoch 15/50
# 210/210 [==============================] - 0s 2ms/step - loss: 0.4057 - accuracy: 0.8316
# Epoch 16/50
# 210/210 [==============================] - 0s 2ms/step - loss: 0.4044 - accuracy: 0.8309
# Epoch 17/50
# 210/210 [==============================] - 0s 2ms/step - loss: 0.4039 - accuracy: 0.8327
# Epoch 18/50
# 210/210 [==============================] - 0s 2ms/step - loss: 0.4027 - accuracy: 0.8328
# Epoch 19/50
# 210/210 [==============================] - 0s 2ms/step - loss: 0.4021 - accuracy: 0.8333
# Epoch 20/50
# 210/210 [==============================] - 0s 2ms/step - loss: 0.4010 - accuracy: 0.8339
# Epoch 21/50
# 210/210 [==============================] - 0s 2ms/step - loss: 0.4004 - accuracy: 0.8340
# Epoch 22/50
# 210/210 [==============================] - 0s 2ms/step - loss: 0.4002 - accuracy: 0.8358
# Epoch 23/50
# 210/210 [==============================] - 0s 2ms/step - loss: 0.3999 - accuracy: 0.8354
# Epoch 24/50
# 210/210 [==============================] - 0s 2ms/step - loss: 0.3993 - accuracy: 0.8351
# Epoch 25/50
# 210/210 [==============================] - 0s 2ms/step - loss: 0.3989 - accuracy: 0.8373
# Epoch 26/50
# 210/210 [==============================] - 1s 3ms/step - loss: 0.3983 - accuracy: 0.8352
# Epoch 27/50
# 210/210 [==============================] - 1s 3ms/step - loss: 0.3979 - accuracy: 0.8364
# Epoch 28/50
# 210/210 [==============================] - 1s 3ms/step - loss: 0.3975 - accuracy: 0.8364
# Epoch 29/50
# 210/210 [==============================] - 1s 3ms/step - loss: 0.3975 - accuracy: 0.8366
# Epoch 30/50
# 210/210 [==============================] - 1s 3ms/step - loss: 0.3969 - accuracy: 0.8360
# Epoch 31/50
# 210/210 [==============================] - 1s 3ms/step - loss: 0.3967 - accuracy: 0.8364
# Epoch 32/50
# 210/210 [==============================] - 1s 3ms/step - loss: 0.3962 - accuracy: 0.8339
# Epoch 33/50
# 210/210 [==============================] - 1s 3ms/step - loss: 0.3963 - accuracy: 0.8357
# Epoch 34/50
# 210/210 [==============================] - 1s 3ms/step - loss: 0.3959 - accuracy: 0.8369
# Epoch 35/50
# 210/210 [==============================] - 1s 3ms/step - loss: 0.3957 - accuracy: 0.8375
# Epoch 36/50
# 210/210 [==============================] - 1s 3ms/step - loss: 0.3954 - accuracy: 0.8357
# Epoch 37/50
# 210/210 [==============================] - 1s 3ms/step - loss: 0.3946 - accuracy: 0.8376
# Epoch 38/50
# 210/210 [==============================] - 1s 3ms/step - loss: 0.3947 - accuracy: 0.8358
# Epoch 39/50
# 210/210 [==============================] - 0s 2ms/step - loss: 0.3940 - accuracy: 0.8373
# Epoch 40/50
# 210/210 [==============================] - 0s 2ms/step - loss: 0.3936 - accuracy: 0.8378
# Epoch 41/50
# 210/210 [==============================] - 0s 2ms/step - loss: 0.3927 - accuracy: 0.8382
# Epoch 42/50
# 210/210 [==============================] - 0s 2ms/step - loss: 0.3920 - accuracy: 0.8399
# Epoch 43/50
# 210/210 [==============================] - 0s 2ms/step - loss: 0.3909 - accuracy: 0.8382
# Epoch 44/50
# 210/210 [==============================] - 0s 2ms/step - loss: 0.3894 - accuracy: 0.8388
# Epoch 45/50
# 210/210 [==============================] - 0s 2ms/step - loss: 0.3885 - accuracy: 0.8415
# Epoch 46/50
# 210/210 [==============================] - 0s 2ms/step - loss: 0.3870 - accuracy: 0.8409
# Epoch 47/50
# 210/210 [==============================] - 0s 2ms/step - loss: 0.3860 - accuracy: 0.8419
# Epoch 48/50
# 210/210 [==============================] - 0s 2ms/step - loss: 0.3842 - accuracy: 0.8430
# Epoch 49/50
# 210/210 [==============================] - 0s 2ms/step - loss: 0.3827 - accuracy: 0.8436
# Epoch 50/50
# 210/210 [==============================] - 0s 2ms/step - loss: 0.3806 - accuracy: 0.8436
# 104/104 [==============================] - 0s 1ms/step
# [[2538   79]
#  [ 450  233]]
